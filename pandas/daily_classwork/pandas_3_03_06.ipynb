# %% [markdown]
# ## handling the outliers

# %%
import pandas as pd 
import numpy as np

# %%
data = {
    "Customer" : ["Aman", "Deep", "Raj", "Sneha"],
    "Age" : [25, np.nan ,40, np.nan],
    "city": ["Delhi" , "Mumbai", "Delhi" , "banglore"]
}

df = pd.DataFrame(data)
df
# Out:
#   Customer   Age      city
# 0     Aman  25.0     Delhi
# 1     Deep   NaN    Mumbai
# 2      Raj  40.0     Delhi
# 3    Sneha   NaN  banglore

# %%
df.drop_duplicates()
# Out:
#   Customer   Age      city
# 0     Aman  25.0     Delhi
# 1     Deep   NaN    Mumbai
# 2      Raj  40.0     Delhi
# 3    Sneha   NaN  banglore

# %% [markdown]
# ## IQR finding

# %% [markdown]
# ## lower bound , upper bound Q1, Q2,Q3

# %% [markdown]
# ## We can find it using quantile(0.25) also for pandas series

# %% [markdown]
# # Z - Score

# %% [markdown]
# ## Column opertions and dara transformation

# %% [markdown]
# 1. adding column

# %%
data = {
    "product" : ["pen" , "notebook" , "marker"],
    "price" :[10,20,400],
    "qty": [100,400,400]
     }

df = pd.DataFrame(data)
df
# Out:
#     product  price  qty
# 0       pen     10  100
# 1  notebook     20  400
# 2    marker    400  400

# %%
df["Revenue"] = df["price"] * df["qty"]
df
# Out:
#     product  price  qty  Revenue
# 0       pen     10  100     1000
# 1  notebook     20  400     8000
# 2    marker    400  400   160000

# %% [markdown]
# ### 2. apply() function , map() functions

# %%
df.price.map(lambda x:x*2)
# Out:
# 0     20
# 1     40
# 2    800
# Name: price, dtype: int64
