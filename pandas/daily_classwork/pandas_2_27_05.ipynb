# %% [markdown]
# ## Pandas file 2 - start - 29-05-26

# %%
import pandas as pd

# %%
# example dataset

#step :- 1 :- load the csv file 

df = pd.read_csv("F:/Tops/python_library/pandas/csv_files/california_housing_test (1).csv")

# %%
data = {
    "customer": ["aman", "priya", "rahul", "sneha", "karan"],
    "city": ["delhi", "mumbai", "delhi", "banglore", "mumbai"],
    "revenue":[12000, 8000,15000,7000,20000]
}

df3 = pd.DataFrame(data)
print(df3)
# Out:
#   customer      city  revenue
# 0     aman     delhi    12000
# 1    priya    mumbai     8000
# 2    rahul     delhi    15000
# 3    sneha  banglore     7000
# 4    karan    mumbai    20000

# %%
### selecting one column in a dataframe

df3["revenue"]
# Out:
# 0    12000
# 1     8000
# 2    15000
# 3     7000
# 4    20000
# Name: revenue, dtype: int64

# %%
df3[["revenue", "city", "customer"]]
# Out:
#    revenue      city customer
# 0    12000     delhi     aman
# 1     8000    mumbai    priya
# 2    15000     delhi    rahul
# 3     7000  banglore    sneha
# 4    20000    mumbai    karan

# %%
# loc function is used to get one hole row  

print(df3.loc[1])

# for particular column value of a particular row value by given the column name 

df3.loc[2, "city"]
# Out:
# customer     priya
# city        mumbai
# revenue       8000
# Name: 1, dtype: object
# 'delhi'

# %%
# iloc function will give the value by passing the row index and column index 

df3.iloc[1 , 1]
# Out:
# 'mumbai'

# %%
# boolean function on df


ram = df3["revenue"] > 100 
print(type(ram))
# Out:
# <class 'pandas.core.series.Series'>

# %%
ram1 = df3[df3["revenue"] >100]

print(type(ram1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
