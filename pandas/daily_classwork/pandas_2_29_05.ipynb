# %% [markdown]
# ## pandas file -2 continue

# %%
#sorting and reindexing

# %%
import pandas as pd

# %%
data = {
    "customer": ["aman", "priya", "rahul", "sneha", "karan"],
    "city": ["delhi", "mumbai", "delhi", "banglore", "mumbai"],
    "revenue":[12000, 8000,15000,7000,20000]
}

df3 = pd.DataFrame(data)
print(df3)
# Out:
#   customer      city  revenue
# 0     aman     delhi    12000
# 1    priya    mumbai     8000
# 2    rahul     delhi    15000
# 3    sneha  banglore     7000
# 4    karan    mumbai    20000

# %%
# sort 

# df.sort_values(by = "column_name")
df3.sort_values(by = ["revenue", "city"])
# Out:
#   customer      city  revenue
# 3    sneha  banglore     7000
# 1    priya    mumbai     8000
# 0     aman     delhi    12000
# 2    rahul     delhi    15000
# 4    karan    mumbai    20000

# %%
# sort using index 

df3.sort_index()
# Out:
#   customer      city  revenue
# 0     aman     delhi    12000
# 1    priya    mumbai     8000
# 2    rahul     delhi    15000
# 3    sneha  banglore     7000
# 4    karan    mumbai    20000

# %%
# ressting index will give new indexing but keep the old also 

sorted_df = df3.sort_values(by = "revenue")

sorted_df.reset_index()
print(df3)
# Out:
#   customer      city  revenue
# 0     aman     delhi    12000
# 1    priya    mumbai     8000
# 2    rahul     delhi    15000
# 3    sneha  banglore     7000
# 4    karan    mumbai    20000

# %%
# removing the old index

sorted_df.reset_index(drop = true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 # removing the old index
# ----> 3 sorted_df.reset_index(drop = true)
#
# NameError: name 'true' is not defined

# %%
# re indexing 

df3.reindex(4,3,1,0,2,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 # re indexing
# ----> 3 df3.reindex(4,3,1,0,2,5)
#
# TypeError: DataFrame.reindex() takes from 1 to 2 positional arguments but 7 were given
