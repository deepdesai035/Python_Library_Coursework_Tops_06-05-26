# %% [markdown]
# ## python file 2 assignment

# %%
# we are going to load the dataset of the calfornia housing one any going to do all the beloew question on it

# %%
import pandas as pd

# %%
dataset = pd.read_csv("F:/Tops/python_library/pandas/csv_files/california_housing_test (1).csv")

dataset
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27         3885             661
# 1       -118.30     34.26                  43         1510             310
# 2       -117.81     33.78                  27         3589             507
# 3       -118.36     33.82                  28           67              15
# 4       -119.67     36.33                  19         1241             244
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                  23         1450             642
# 2996    -118.14     34.06                  27         5257            1082
# 2997    -119.70     36.30                  10          956             201
# 2998    -117.12     34.10                  40           96              14
# 2999    -119.63     34.42                  42         1765             263
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# 1
#
# Display the entire dataset.

# %%
print(dataset)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27         3885             661
# 1       -118.30     34.26                  43         1510             310
# 2       -117.81     33.78                  27         3589             507
# 3       -118.36     33.82                  28           67              15
# 4       -119.67     36.33                  19         1241             244
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                  23         1450             642
# 2996    -118.14     34.06                  27         5257            1082
# 2997    -119.70     36.30                  10          956             201
# 2998    -117.12     34.10                  40           96              14
# 2999    -119.63     34.42                  42         1765             263
#
#       population  households  median_income  median_house_value
# ...

# %%
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                  27         3885             661
# 1    -118.30     34.26                  43         1510             310
# 2    -117.81     33.78                  27         3589             507
# 3    -118.36     33.82                  28           67              15
# 4    -119.67     36.33                  19         1241             244
#
#    population  households  median_income  median_house_value
# 0        1537         606         6.6085              344700
# 1         809         277         3.5990              176500
# 2        1484         495         5.7934              270500
# 3          49          11         6.1359              330000
# 4         850         237         2.9375               81700

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   int64
#  3   total_rooms         3000 non-null   int64
#  4   total_bedrooms      3000 non-null   int64
#  5   population          3000 non-null   int64
#  6   households          3000 non-null   int64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   int64
# dtypes: float64(3), int64(6)
# memory usage: 211.1 KB

# %%
dataset.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %% [markdown]
# 2
#
# Select only the median_house_value column.

# %%
dataset["median_house_value"]
# Out:
# 0       344700
# 1       176500
# 2       270500
# 3       330000
# 4        81700
#          ...
# 2995    225000
# 2996    237200
# 2997     62000
# 2998    162500
# 2999    500001
# Name: median_house_value, Length: 3000, dtype: int64

# %% [markdown]
# 3
#
# Select the Customer and Revenue columns together.

# %%
dataset[["median_income" , "median_house_value"]]
# Out:
#       median_income  median_house_value
# 0            6.6085              344700
# 1            3.5990              176500
# 2            5.7934              270500
# 3            6.1359              330000
# 4            2.9375               81700
# ...             ...                 ...
# 2995         1.1790              225000
# 2996         3.3906              237200
# 2997         2.2895               62000
# 2998         3.2708              162500
# 2999         8.5608              500001
#
# [3000 rows x 2 columns]

# %% [markdown]
# 4
#
# Using loc, display the second row of the dataset.

# %%
dataset.loc[1]
# Out:
# longitude               -118.300
# latitude                  34.260
# housing_median_age        43.000
# total_rooms             1510.000
# total_bedrooms           310.000
# population               809.000
# households               277.000
# median_income              3.599
# median_house_value    176500.000
# Name: 1, dtype: float64

# %% [markdown]
# 5
#
# Using iloc, display the third row of the dataset.

# %%
dataset.iloc[[2,]]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2    -117.81     33.78                  27         3589             507
#
#    population  households  median_income  median_house_value
# 2        1484         495         5.7934              270500

# %% [markdown]
# 6
#
# Using loc, retrieve the Revenue value of Rahul.

# %%
dataset.loc[100 , "total_rooms"]
# Out:
# np.int64(2120)

# %% [markdown]
# 7
#
# Filter the dataset to show customers whose Revenue is greater than 10000.

# %%
dataset.loc[dataset["total_rooms"] > 1000 , "total_bedrooms"]
# Out:
# 0        661
# 1        310
# 2        507
# 4        244
# 5        213
#         ...
# 2991     718
# 2993     510
# 2995     642
# 2996    1082
# 2999     263
# Name: total_bedrooms, Length: 2636, dtype: int64

# %% [markdown]
# 8
#
# Display customers who belong to Mumbai.

# %%
dataset[dataset["total_bedrooms"] == 1000]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1204    -121.64      36.8                  18         5915            1000
#
#       population  households  median_income  median_house_value
# 1204        2975         975         4.5812              255200
