# %% [markdown]
# ### Concatenation of arrays

# %% [markdown]
# ## concatenation on the basis on axis , acis = 0 is row wise and axis = 1 is cloumn wise

# %% [markdown]
# ### need to learn the d stack , it is used to increase the dimension of the array

# %% [markdown]
# ### array splitting ,
# ### insert , append , delete

# %%
arr = np.array([10,20,30])

print("Insert", np.insert(arr,1,15))
print(arr)
print("append",np.append(arr,20))
print(arr)
print("delete", np.delete(arr,4))
print(arr)

# ()here the thing is that the delete will not affect the original array

# %% [markdown]
# ### view and copy of the array
