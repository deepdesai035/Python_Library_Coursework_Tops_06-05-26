# %%
import numpy as np

price of products 

name of products :- 

name = np.array([ball,bat,wickets, bails,gloves])

prices = np.array([100,200,300,np.nan,250])

# quantity of products sold 

quantity = np.array([10,5,8,3,7,6])


print("Prices :- ", prices )
print("Quantity :- ", quantity)
